# %% [markdown]
# # Prepare a prediction model for profit of 50 startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.
#
# R&D Spend -- Research and devolop spend in the past few years
# Administration -- spend on administration in the past few years
# Marketing Spend -- spend on Marketing in the past few years
# State -- states from which data is collected
# Profit  -- profit of each state in the past few years

# %%
#Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf

# %%
#Load the dataset and Explore it
startup = pd.read_csv('C:/Users/chowd/OneDrive/Desktop/Data Science/Assignments/50_Startups.csv')
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Exploratory Data Analysis
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
startup.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Check for missing values
startup.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
# Check for duplicated records
startup[startup.duplicated()]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
# Rename the columns
startup_1 = startup.rename({'R&D Spend': 'RDS','Administration': 'ADM','Marketing Spend': 'MKS'}, axis=1)

# %%
# Scatterplot between variables along with histograms
sns.set_style(style='darkgrid')
sns.pairplot(startup_1)
# Out:
# C:\Users\chowd\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Model Building
model = smf.ols('Profit~RDS+ADM+MKS',data=startup_1).fit()

# %%
# Model Testing
model.params # Co-efficient of model
# Out:
# Intercept    50122.192990
# RDS              0.805715
# ADM             -0.026816
# MKS              0.027228
# dtype: float64

# %%
# Summary of model
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):           4.53e-30
# Time:                        15:40:17   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %% [markdown]
# The Accuracy of model is 95.1%

# %%
# Since the p value for Administration and Marketing Spend is > 0.05, build simple linear regression and Mutiple Linear Regression

# %%
slr_adm = smf.ols('Profit~ADM',data=startup_1).fit()

# %%
slr_adm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):              0.162
# Time:                        15:44:00   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %% [markdown]
# After we build a simple linear regression model, we can see that administration has no significant p value.

# %%
# Build a simple linear model to check the column Marketing

slr_mar = smf.ols('Profit~MKS',data=startup_1).fit()

# %%
slr_mar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):           4.38e-10
# Time:                        15:46:56   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept       6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...

# %% [markdown]
# Since the p value is less than 0.05 we can say that is a significant column

# %%
# Build the Multi Linear regression model of Administration and Marketing together to check for collinearity problem
slr_AM = smf.ols('Profit~ADM+MKS',data=startup_1).fit()

# %%
slr_AM.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     36.71
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):           2.50e-10
# Time:                        15:50:52   Log-Likelihood:                -577.13
# No. Observations:                  50   AIC:                             1160.
# Df Residuals:                      47   BIC:                             1166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.022e+04   1.77e+04      1.143      0.259   -1.54e+04    5.58e+04
# ...

# %% [markdown]
# When we build the model together both of the columns have significant p value

# %% [markdown]
# # Model Validation Techniques

# %% [markdown]
# # There are two techniques

# %% [markdown]
# # 1) Collinearity Check - VIF

# %% [markdown]
# # 2) Residual Analysis

# %% [markdown]
# Calculating Variance Inflation Factor (VIF) = 1/1-r^2

# %%
rsq_rds = smf.ols('RDS~ADM+MKS',data=startup_1).fit().rsquared
vif_rds = 1/(1-rsq_rds)
vif_rds
# Out:
# 2.4689030699947017

# %%
rsq_adm = smf.ols('ADM~RDS+MKS',data=startup_1).fit().rsquared
vif_adm = 1/(1-rsq_adm)
vif_adm
# Out:
# 1.1750910070550458

# %%
rsq_mks = smf.ols('MKS~RDS+ADM',data=startup_1).fit().rsquared
vif_mks = 1/(1-rsq_mks)
vif_mks
# Out:
# 2.3267732905308773

# %%
# Storing vif values in a data frame
d1 = {'Variables': ['RDS','ADM','MKS'], 'VIF': [vif_rds,vif_adm,vif_mks]}
Vif_frame = pd.DataFrame(d1)
Vif_frame
# Out:
#   Variables       VIF
# 0       RDS  2.468903
# 1       ADM  1.175091
# 2       MKS  2.326773

# %% [markdown]
# Since no value of VIF is greater than 20, we can say that there is no collinearity problem. So, we shall consider all columns
# for building the model.

# %%
# Residual Analysis

# %%
# Test for Normality of Residuals (Q-Q Plot)
import statsmodels.api as sm
sns.set_style(style='darkgrid')
qqplot=sm.qqplot(model.resid,line='q') # Line = 45 to draw the diagonal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-10000))
# Out:
# [array([14, 15, 48, 49], dtype=int64)]

# %% [markdown]
# Residual Plot for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual
# values)

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std() # User Defined Function Z = (x-mu)/sigma

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized Residual values')
plt.show()

# %% [markdown]
# Residual vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model,"RDS",fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model,"ADM",fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model,"MKS",fig=fig)
plt.show()

# %% [markdown]
# # Model Detection Diagnostics

# %% [markdown]
# # Detecting Infulencers / Outliers

# %%
# Cooks Distance
model_infulence = model.get_influence()
(c, _) = model_infulence.cooks_distance

# %%
# Plot the influencers values using stem plot
sns.set_style(style='darkgrid')
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(startup_1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %% [markdown]
# There are no datapoints whose value is greater than 0.5

# %%
# High Influence Plots
fig,ax=plt.subplots(figsize=(15,10))
fig=influence_plot(model,ax = ax)

# %%
k = startup_1.shape[1]     # k = no.of features/columns & n = no. of datapoints
n = startup_1.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
startup_1[startup_1.index.isin([49])]
# Out:
#     RDS       ADM       MKS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
startup_1.shape
# Out:
# (50, 5)

# %% [markdown]
# # Improving The Model

# %%
# Discard the data points which are influencers and reasign the row number (reset_index())
startup_2 = startup_1.copy()
startup_2
# Out:
#           RDS        ADM        MKS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
startup_2 = startup_1.drop(startup_1.index[[49]],axis=0).reset_index(drop=True)
startup_2
# Out:
#           RDS        ADM        MKS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# # Model Deletion Diagnostics and Final Model

# %%
Final_Model = smf.ols('Profit~RDS+ADM+MKS',data=startup_2).fit()

# %%
Final_Model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):           8.85e-32
# Time:                        16:42:22   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.238e+04   5542.657      9.451      0.000    4.12e+04    6.35e+04
# ...

# %% [markdown]
# Thus the accuracy of the model has improved to 96.1%

# %% [markdown]
# # Model Predictions

# %%
# New data for prediction
new_data = pd.DataFrame({'RDS':78000,'ADM':127864.55,'MKS':249839.44},index=[1])
new_data
# Out:
#      RDS        ADM        MKS
# 1  78000  127864.55  249839.44

# %%
# Manual Prediction
Final_Model.predict(new_data)
# Out:
# 1    116922.172202
# dtype: float64

# %%
# Automatic Prediction
pred_y = Final_Model.predict(startup_2)
pred_y
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %%
# Table Containing R square values
d2 ={'Prepared_models':['Model','Final_Model'],'Rsquared':[model.rsquared,Final_Model.rsquared]}
table = pd.DataFrame(d2)
table
# Out:
#   Prepared_models  Rsquared
# 0           Model  0.950746
# 1     Final_Model  0.961316

# %% [markdown]
# # Consider only the below columns and prepare a prediction model for predicting Price.

# %% [markdown]
# Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]
#
#
#
# Model -- model of the car
# Price  -- Offer Price in EUROs
# Age_08_04 -- Age in months as in August 2004
# Mfg_Month -- Manufacturing month (1-12)
# Mfg_Year	-- Manufacturing Year
# KM -- Accumulated Kilometers on odometer
# Fuel_Type	 -- Fuel Type (Petrol, Diesel, CNG)
# HP -- Horse Power
# Met_Color	 -- Metallic Color?  (Yes=1, No=0)
# Color -- Color (Blue, Red, Grey, Silver, Black, etc.)
# Automatic	-- Automatic ( (Yes=1, No=0)
# cc -- Cylinder Volume in cubic centimeters
# Doors -- Number of doors
# Cylinders	-- Number of cylinders
# Gears -- Number of gear positions
# Quarterly_Tax -- Quarterly road tax in EUROs
# Weight -- Weight in Kilograms
# Mfr_Guarantee -- Within Manufacturer's Guarantee period  (Yes=1, No=0)
# BOVAG_Guarantee -- BOVAG (Dutch dealer network) Guarantee  (Yes=1, No=0)
# Guarantee_Period -- 	Guarantee period in months
# ABS -- Anti-Lock Brake System (Yes=1, No=0)
# Airbag_1 -- Driver_Airbag  (Yes=1, No=0)
# Airbag_2 -- Passenger Airbag  (Yes=1, No=0)
# Airco -- Airconditioning  (Yes=1, No=0)
# Automatic_airco -- Automatic Airconditioning  (Yes=1, No=0)
# Boardcomputer -- Boardcomputer  (Yes=1, No=0)
# CD_Player -- CD Player  (Yes=1, No=0)
# Central_Lock -- Central Lock  (Yes=1, No=0)
# Powered_Windows -- Powered Windows  (Yes=1, No=0)
# Power_Steering -- Power Steering  (Yes=1, No=0)
# Radio -- Radio  (Yes=1, No=0)
# Mistlamps	-- Mistlamps  (Yes=1, No=0)
# Sport_Model -- Sport Model  (Yes=1, No=0)
# Backseat_Divider -- Backseat Divider  (Yes=1, No=0)
# Metallic_Rim --Metallic Rim  (Yes=1, No=0)
# Radio_cassette -- Radio Cassette  (Yes=1, No=0)
# Tow_Bar -- Tow Bar  (Yes=1, No=0)

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import influence_plot

# %%
# Import Dataset
toyota = pd.read_csv('C:/Users/chowd/OneDrive/Desktop/Data Science/Assignments/ToyotaCorolla.csv', encoding='latin1')
toyota
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
# Exploratory Data Analysis
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
toyota2 = pd.concat([toyota.iloc[:,2:4],toyota.iloc[:,6:7],toyota.iloc[:,8:9],toyota.iloc[:,12:14],toyota.iloc[:,15:18]],axis=1)
toyota2
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota3 = toyota2.rename({'Age_08_04':'Age','cc':'CC','Quarterly_Tax':'QT'},axis=1)
toyota3
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
toyota3[toyota3.duplicated()]
# Out:
#      Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 113  24950    8  13253  116  2000      5      5  234    1320

# %%
toyota4=toyota3.drop_duplicates().reset_index(drop=True)
toyota4
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
toyota4.describe()
# Out:
#               Price          Age             KM           HP            CC  \
# count   1435.000000  1435.000000    1435.000000  1435.000000   1435.000000
# mean   10720.915679    55.980488   68571.782578   101.491986   1576.560976
# std     3608.732978    18.563312   37491.094553    14.981408    424.387533
# min     4350.000000     1.000000       1.000000    69.000000   1300.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.000000
# 50%     9900.000000    61.000000   63451.000000   110.000000   1600.000000
# 75%    11950.000000    70.000000   87041.500000   110.000000   1600.000000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.000000
#
#              Doors        Gears           QT       Weight
# count  1435.000000  1435.000000  1435.000000  1435.000000
# mean      4.032753     5.026481    87.020209  1072.287108
# std       0.952667     0.188575    40.959588    52.251882
# min       2.000000     3.000000    19.000000  1000.000000
# ...

# %%
# Correlation Analysis
toyota4.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# Age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# CC      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# Age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# CC      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(toyota4)
# Out:
# C:\Users\chowd\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Model Building
model = smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit()

# %%
# Model Testing
model.params # Finding coefficient Parameters
# Out:
# Intercept   -5472.540368
# Age          -121.713891
# KM             -0.020737
# HP             31.584612
# CC             -0.118558
# Doors          -0.920189
# Gears         597.715894
# QT              3.858805
# Weight         16.855470
# dtype: float64

# %%
# Finding t values and p values
model.tvalues , np.round(model.pvalues,5)
# Out:
# (Intercept    -3.875273
#  Age         -46.551876
#  KM          -16.552424
#  HP           11.209719
#  CC           -1.316436
#  Doors        -0.023012
#  Gears         3.034563
#  QT            2.944198
#  Weight       15.760663
#  dtype: float64,
#  Intercept    0.00011
#  Age          0.00000
#  KM           0.00000
#  HP           0.00000
#  CC           0.18824
#  Doors        0.98164
#  Gears        0.00245
#  QT           0.00329
#  Weight       0.00000
#  dtype: float64)

# %%
# Finding rsquared values 
model.rsquared , model.rsquared_adj
# Out:
# (0.8625200256947, 0.8617487495415146)

# %% [markdown]
# Model Accuracy is 86.17%

# %% [markdown]
# Build SLR and MLR models for insignificant variables 'CC' and 'Doors'
# Also find their t values and p values

# %%
slr_c=smf.ols('Price~CC',data=toyota4).fit()
slr_c.tvalues , slr_c.pvalues # CC has significant p value
# Out:
# (Intercept    24.879592
#  CC            4.745039
#  dtype: float64,
#  Intercept    7.236022e-114
#  CC            2.292856e-06
#  dtype: float64)

# %%
slr_c=smf.ols('Price~Doors',data=toyota4).fit()
slr_c.tvalues , slr_c.pvalues # Doors has significant p value
# Out:
# (Intercept    19.421546
#  Doors         7.070520
#  dtype: float64,
#  Intercept    8.976407e-75
#  Doors        2.404166e-12
#  dtype: float64)

# %%
slr_c=smf.ols('Price~CC+Doors',data=toyota4).fit()
slr_c.tvalues , slr_c.pvalues # CC and Doors has significant p value
# Out:
# (Intercept    12.786341
#  CC            4.268006
#  Doors         6.752236
#  dtype: float64,
#  Intercept    1.580945e-35
#  CC           2.101878e-05
#  Doors        2.109558e-11
#  dtype: float64)

# %% [markdown]
# #  Model Validation Techniques

# %% [markdown]
# # Two Techniques: Collinearity Check and Residual Analysis

# %%
# Collinearity Check
# Calculate VIF = 1/(1-Rsquare) for all independent variables

rsq_age=smf.ols('Age~KM+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~Age+HP+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~Age+KM+CC+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_CC=smf.ols('CC~Age+KM+HP+Doors+Gears+QT+Weight',data=toyota4).fit().rsquared
vif_CC=1/(1-rsq_CC)

rsq_Doors=smf.ols('Doors~Age+KM+HP+CC+Gears+QT+Weight',data=toyota4).fit().rsquared
vif_Doors=1/(1-rsq_Doors)

rsq_Gears=smf.ols('Gears~Age+KM+HP+CC+Doors+QT+Weight',data=toyota4).fit().rsquared
vif_Gears=1/(1-rsq_Gears)

rsq_QT=smf.ols('QT~Age+KM+HP+CC+Doors+Gears+Weight',data=toyota4).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_Weight=smf.ols('Weight~Age+KM+HP+CC+Doors+Gears+QT',data=toyota4).fit().rsquared
vif_Weight=1/(1-rsq_Weight)

# Putting the values in dataframe format
d1={'Variables':['Age','KM','HP','CC','Doors','Gears','QT','Weight'],
   'Vif':[vif_age,vif_KM,vif_HP,vif_CC,vif_Doors,vif_Gears,vif_QT,vif_Weight]}
vif_df=pd.DataFrame(d1)
vif_df
# Out:
#   Variables       Vif
# 0       Age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        CC  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %% [markdown]
# None variable has VIF>20, No collinearity, so consider all variables in regression equation

# %%
# Residual Analysis
# Test for normality of residuals (Q-Q Plot) using residual model (model.resid)
sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
# Outlier detection from above QQ plot of residuals
list(np.where(model.resid>6000))
# Out:
# [array([109, 146, 522], dtype=int64)]

# %%
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959], dtype=int64)]

# %%
# Test for Homoscedasticity or Heteroscedasticity (plotting model's standardized fitted values vs standardized residual values)
def standard_values(vals) : return (vals-vals.mean())/vals.std() # User defined z = (x - mu) / sigma

# %%
plt.scatter(standard_values(model.fittedvalues),standard_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardized fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# Test for errors or residuals vs regressors or independent 'x' variables or predictors
# using residual regression plot code graphics.plot_regress_exog(model,'x',fig)

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Age',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'QT',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()

# %% [markdown]
# # Model Deletion Diagnostics(checking Outliers or Influencers)
# # Two Techniques: 1. Cook's Distance and 2. Leverage value

# %%
# Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([7.22221054e-03, 3.94547973e-03, 5.44224039e-03, ...,
#        8.04110550e-07, 6.99854767e-04, 1.08408002e-02])

# %%
# Plot the influencers using the stem plot
fig = plt.figure(figsize=(20,8))
plt.stem(np.arange(len(toyota4)),np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c), np.max(c)
# Out:
# (80, 78.72950582248895)

# %%
# Leverage value using high influence points : points beyond leverage_cutoff value are influencers
fig,ax=plt.subplots(figsize=(19,19))
fig=influence_plot(model,ax = ax)

# %%
# Leverage cutoff value = 3*(k+1)/n ; k = no.of features/columns & n = no.of datapoints
k = toyota4.shape[1]
n = toyota4.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.020905923344947737

# %%
toyota4[toyota4.index.isin([80])]
# Out:
#     Price  Age     KM   HP     CC  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %% [markdown]
# # Improving The Model

# %%
# Creating a copy of data so that original dataset is not affected
toyo_new=toyota4.copy()
toyo_new
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1430   7500   69  20544   86  1300      3      5   69    1025
# 1431  10845   72  19000   86  1300      3      5   69    1015
# 1432   8500   71  17016   86  1300      3      5   69    1015
# 1433   7250   70  16916   86  1300      3      5   69    1015
# 1434   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
# Discard the datapoints which are influencers and reassign the row number
toyota5 = toyo_new.drop(toyo_new.index[[80]],axis=0).reset_index(drop=True)
toyota5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %% [markdown]
# #  Model Deletion Diagnostics and Final Model

# %%
while np.max(c)>0.5:
    model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota5).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    toyota5 = toyota5.drop(toyota5.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    toyota5
else:
    final_model=smf.ols('Price~Age+KM+HP+CC+Doors+Gears+QT+Weight',data=toyota5).fit()
    final_model.rsquared , final_model.aic
    print("Thus Model accuracy is improved to",final_model.rsquared)
# Out:
# Thus Model accuracy is improved to 0.8882395145171204

# %%
final_model.rsquared
# Out:
# 0.8882395145171204

# %%
toyota5
# Out:
#       Price  Age     KM   HP    CC  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1426   7500   69  20544   86  1300      3      5   69    1025
# 1427  10845   72  19000   86  1300      3      5   69    1015
# 1428   8500   71  17016   86  1300      3      5   69    1015
# 1429   7250   70  16916   86  1300      3      5   69    1015
# 1430   6950   76      1  110  1600      5      5   19    1114
#
# [1431 rows x 9 columns]

# %% [markdown]
# # Model Predictions

# %%
# Say new data for prediction is 
new_data = pd.DataFrame({'Age':12,"KM":40000,'HP':80,'CC':1300,'Doors':4,'Gears':5,'QT':69,'Weight':1012},index=[0])
new_data
# Out:
#    Age     KM  HP    CC  Doors  Gears  QT  Weight
# 0   12  40000  80  1300      4      5  69    1012

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    14341.570181
# dtype: float64

# %%
# Automatic Prediction of price with 90.02% accuracy
pred_y=final_model.predict(toyota5)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64

# %%
# Table Containing R square values
d2 ={'Prepared_models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table = pd.DataFrame(d2)
table
# Out:
#   Prepared_models  Rsquared
# 0           Model  0.883968
# 1     Final_Model  0.888240
